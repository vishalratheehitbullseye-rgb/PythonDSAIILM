# %%
class Student:
    pass
st = Student()
print(type(st))
st.name = "Vishal"
st.roll_no = 1
print(st.name + " " + str(st.roll_no))
# Out:
# <class '__main__.Student'>
# Vishal 1

# %%
class Student:
    def __init__(self, name : str, roll_no : int ):
        self.__name = name
        self.__roll_no = roll_no
        pass
st = Student("Vishal", 1)
# print(st.name)
st.__name = "Vishal"
print(st.__name)
# Out:
# Vishal
