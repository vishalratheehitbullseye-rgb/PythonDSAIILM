# %%
#steps to write any recursive program
# --> create a function prototype
# --> give a definition to it
# --> write rec case/ breakdown


# Min/Max of homogenous list using recursion
a = [100,2,300,4]
def minEleFinder(a : list[int], ind : int) :
    # base
    if len(a)-1 == ind : return a[ind]
    # rec
    # a1 = a[1:]
    return min(a[ind], minEleFinder(a, ind+1))
    
print(minEleFinder(a, 0))
# check whether a string is palindrome or not using recursion
# check whether a given number is palindrome or not using recursion
s = "racecar"
# Out:
# 2

# %%
n = 1234321
# revn = 0
# temp = n
# while temp>0 : 
#     revn *= 10;
#     revn += temp%10
#     temp //= 10
# print(revn)
def revNum(n : int, revn : int):
    # base
    if n == 0: return revn
    # rec
    revn *= 10
    revn += n%10
    return revNum(n//10, revn)
print(n == revNum(n,0))
# Out:
# True

# %%
a = [(1,2,3),4,5]
t = ([1,2,3],4,5)
# a[0][0] = 10
t[0][0] = 10
print(t[0][0])
# Out:
# 10
